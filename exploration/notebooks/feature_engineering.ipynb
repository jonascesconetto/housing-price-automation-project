# %% [markdown]
# ### Feature Engineering:
#
# Pré-processamento de features do conjunto de dados.
#
# * Verificar registros duplicados.
# * Registros faltantes.
# * Variáveis temporais.
# * Transformação e padronização de valores.
# * Encoding de variáveis categóricas.
# * Formação e criação de novas features.
# * Exclusão de features redundantes.
# * Verificação e remoção de multi-colinearidade.

# %% [markdown]
# ### Import necessary libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math as mt
import matplotlib.pyplot as plt
import warnings
from scipy import stats
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline
pd.set_option('display.max_columns',None)
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Load Dataset:

# %%
df = pd.read_csv('../data/zillow.csv')
df.shape
# Out:
# (30295, 60)

# %%
df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  17073783                    NaN                       NaN           NaN
# 1  17088994                    NaN                       NaN           NaN
# 2  17100444                    NaN                       NaN           NaN
# 3  17102429                    NaN                       NaN           NaN
# 4  17109604                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.5         3.0                  NaN                    NaN
# 1          1.0         2.0                  NaN                    NaN
# 2          2.0         3.0                  NaN                    NaN
# 3          1.5         2.0                  NaN                    NaN
# 4          2.5         4.0                  NaN                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet  \
# 0                2.5         NaN                     548.0
# 1                1.0         NaN                     777.0
# 2                2.0         NaN                    1101.0
# 3                1.5         NaN                    1554.0
# 4                2.5         NaN                    1305.0
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  finishedsquarefeet13  \
# 0                        1264.0                1264.0                   NaN
# 1                         777.0                 777.0                   NaN
# 2                        1101.0                1101.0                   NaN
# 3                        1554.0                1554.0                   NaN
# 4                        2415.0                2415.0                   NaN
#
#    finishedsquarefeet15  finishedsquarefeet50  finishedsquarefeet6  fips  \
# 0                   NaN                 548.0                  NaN  6111
# 1                   NaN                 777.0                  NaN  6111
# 2                   NaN                1101.0                  NaN  6111
# 3                   NaN                1554.0                  NaN  6111
# 4                   NaN                1305.0                  NaN  6111
#
#    fireplacecnt  fullbathcnt  garagecarcnt  garagetotalsqft hashottuborspa  \
# 0           NaN          2.0           2.0              0.0            NaN
# 1           NaN          1.0           1.0              0.0            NaN
# 2           NaN          2.0           2.0            441.0            NaN
# 3           1.0          1.0           2.0            460.0            NaN
# 4           1.0          2.0           2.0            665.0            NaN
#
#    heatingorsystemtypeid  latitude  longitude  lotsizesquarefeet  poolcnt  \
# 0                    NaN  34303597 -119287236             1735.0      NaN
# 1                    NaN  34272866 -119198911                NaN      NaN
# 2                    NaN  34340801 -119079610             6569.0      NaN
# 3                    NaN  34354313 -119076405             7400.0      NaN
# 4                    NaN  34266578 -119165392             6326.0      NaN
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          NaN
# 3          NaN           NaN          NaN          NaN
# 4          NaN           NaN          NaN          NaN
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                      1128                    265                NaN
# 1                      1129                    266                NaN
# 2                      1111                    261                NaN
# 3                      1110                    261                NaN
# 4                      1111                    261                NaN
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.111002e+07       34543.0            2061                   NaN
# 1            6.111002e+07       34543.0            2061                   NaN
# 2            6.111001e+07       26965.0            2061                   NaN
# 3            6.111001e+07       26965.0            2061                   NaN
# 4            6.111001e+07       34543.0            2061                   NaN
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      97081.0      5.0          NaN                  1.0
# 1      97083.0      4.0          NaN                  NaN
# 2      97113.0      5.0          NaN                  NaN
# 3      97113.0      5.0          NaN                  1.0
# 4      97084.0      8.0          NaN                  1.0
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      NaN               128.0                 NaN
# 1                     NaN      NaN               198.0                 NaN
# 2                     NaN      NaN                 NaN                 NaN
# 3                     NaN      NaN                 NaN                 NaN
# 4                     NaN      NaN                 NaN                 NaN
#
#    yearbuilt  numberofstories fireplaceflag  structuretaxvaluedollarcnt  \
# 0     1986.0              2.0           NaN                    115087.0
# 1     1990.0              1.0           NaN                    143809.0
# 2     1956.0              1.0           NaN                     33619.0
# 3     1965.0              1.0           NaN                     45609.0
# 4     1984.0              2.0           NaN                    277000.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           191811.0            2015                76724.0    2015.06
# 1           239679.0            2015                95870.0    2581.30
# 2            47853.0            2015                14234.0     591.64
# 3            62914.0            2015                17305.0     682.78
# 4           554000.0            2015               277000.0    5886.92
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                NaN                 NaN         6.111002e+13    0.0953
# 1                NaN                 NaN         6.111002e+13    0.0198
# 2                NaN                 NaN         6.111001e+13    0.0060
# 3                NaN                 NaN         6.111001e+13   -0.0566
# 4                NaN                 NaN         6.111001e+13    0.0573
#
#   transactiondate
# 0      2016-01-27
# 1      2016-03-30
# 2      2016-05-27
# 3      2016-06-07
# 4      2016-08-08

# %% [markdown]
# ### Verificando registros duplicados.

# %%
duplicate = df[df.duplicated('parcelid')]
duplicate.shape
# Out:
# (38, 60)

# %% [markdown]
# #### Excluindo os registros com id's duplicados.

# %%
df.drop_duplicates(subset ="parcelid", keep = 'first', inplace = True)
df.shape
# Out:
# (30257, 60)

# %% [markdown]
# ###  Verificando Missing Values.

# %%
missing_val = [var for var in df.columns if df[var].isnull().sum()>0]
df[missing_val].isnull().sum()
# Out:
# airconditioningtypeid           20565
# architecturalstyletypeid        30167
# basementsqft                    30243
# buildingclasstypeid             30249
# buildingqualitytypeid           10998
# calculatedbathnbr                 391
# decktypeid                      30040
# finishedfloor1squarefeet        27997
# calculatedfinishedsquarefeet      217
# finishedsquarefeet12             1548
# finishedsquarefeet13            30246
# finishedsquarefeet15            29060
# finishedsquarefeet50            27997
# finishedsquarefeet6             30134
# fireplacecnt                    27033
# fullbathcnt                       391
# garagecarcnt                    20240
# garagetotalsqft                 20240
# hashottuborspa                  29495
# heatingorsystemtypeid           11429
# lotsizesquarefeet                3363
# poolcnt                         24241
# poolsizesum                     29931
# pooltypeid10                    29887
# pooltypeid2                     29865
# pooltypeid7                     24633
# propertyzoningdesc              10665
# regionidcity                      639
# regionidneighborhood            18206
# regionidzip                        12
# storytypeid                     30243
# threequarterbathnbr             26180
# typeconstructiontypeid          30151
# unitcnt                         10656
# yardbuildingsqft17              29362
# yardbuildingsqft26              30224
# yearbuilt                         248
# numberofstories                 23355
# fireplaceflag                   30168
# structuretaxvaluedollarcnt        118
# taxvaluedollarcnt                   1
# landtaxvaluedollarcnt               1
# taxamount                           1
# taxdelinquencyflag              29679
# taxdelinquencyyear              29679
# censustractandblock               199
# dtype: int64

# %% [markdown]
# ### Excluindo colunas que tenham mais que 60% de registros missing.

# %%
df.shape
# Out:
# (30257, 60)

# %% [markdown]
# #### Estabelecendo o limite para filtragem.

# %%
limit = df.shape[0] * 0.6
vars_dropped = [var for var in missing_val if df[var].isnull().sum() > limit]

# %% [markdown]
# #### Variáveis que serão excluídas.

# %%
vars_dropped
# Out:
# ['airconditioningtypeid',
#  'architecturalstyletypeid',
#  'basementsqft',
#  'buildingclasstypeid',
#  'decktypeid',
#  'finishedfloor1squarefeet',
#  'finishedsquarefeet13',
#  'finishedsquarefeet15',
#  'finishedsquarefeet50',
#  'finishedsquarefeet6',
#  'fireplacecnt',
#  'garagecarcnt',
#  'garagetotalsqft',
#  'hashottuborspa',
#  'poolcnt',
#  'poolsizesum',
#  'pooltypeid10',
#  'pooltypeid2',
#  'pooltypeid7',
#  'regionidneighborhood',
#  'storytypeid',
#  'threequarterbathnbr',
#  'typeconstructiontypeid',
#  'yardbuildingsqft17',
#  'yardbuildingsqft26',
#  'numberofstories',
#  'fireplaceflag',
#  'taxdelinquencyflag',
#  'taxdelinquencyyear']

# %% [markdown]
# #### Excluindo as variáveis.

# %%
df.drop(columns=vars_dropped, axis=1, inplace=True)

# %%
df.shape
# Out:
# (30257, 31)

# %%
df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
#
#    fips  fullbathcnt  heatingorsystemtypeid  latitude  longitude  \
# 0  6111          2.0                    NaN  34303597 -119287236
# 1  6111          1.0                    NaN  34272866 -119198911
# 2  6111          2.0                    NaN  34340801 -119079610
# 3  6111          1.0                    NaN  34354313 -119076405
# 4  6111          2.0                    NaN  34266578 -119165392
#
#    lotsizesquarefeet propertycountylandusecode  propertylandusetypeid  \
# 0             1735.0                      1128                    265
# 1                NaN                      1129                    266
# 2             6569.0                      1111                    261
# 3             7400.0                      1110                    261
# 4             6326.0                      1111                    261
#
#   propertyzoningdesc  rawcensustractandblock  regionidcity  regionidcounty  \
# 0                NaN            6.111002e+07       34543.0            2061
# 1                NaN            6.111002e+07       34543.0            2061
# 2                NaN            6.111001e+07       26965.0            2061
# 3                NaN            6.111001e+07       26965.0            2061
# 4                NaN            6.111001e+07       34543.0            2061
#
#    regionidzip  roomcnt  unitcnt  yearbuilt  structuretaxvaluedollarcnt  \
# 0      97081.0      5.0      NaN     1986.0                    115087.0
# 1      97083.0      4.0      NaN     1990.0                    143809.0
# 2      97113.0      5.0      NaN     1956.0                     33619.0
# 3      97113.0      5.0      NaN     1965.0                     45609.0
# 4      97084.0      8.0      NaN     1984.0                    277000.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           191811.0            2015                76724.0    2015.06
# 1           239679.0            2015                95870.0    2581.30
# 2            47853.0            2015                14234.0     591.64
# 3            62914.0            2015                17305.0     682.78
# 4           554000.0            2015               277000.0    5886.92
#
#    censustractandblock  logerror transactiondate
# 0         6.111002e+13    0.0953      2016-01-27
# 1         6.111002e+13    0.0198      2016-03-30
# 2         6.111001e+13    0.0060      2016-05-27
# 3         6.111001e+13   -0.0566      2016-06-07
# 4         6.111001e+13    0.0573      2016-08-08

# %% [markdown]
# ### Diferença entre o ano que a casa foi construída para o ano que foi vendida.

# %%
df['yeardifference'] = df['assessmentyear'] - df['yearbuilt']
df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
#
#    fips  fullbathcnt  heatingorsystemtypeid  latitude  longitude  \
# 0  6111          2.0                    NaN  34303597 -119287236
# 1  6111          1.0                    NaN  34272866 -119198911
# 2  6111          2.0                    NaN  34340801 -119079610
# 3  6111          1.0                    NaN  34354313 -119076405
# 4  6111          2.0                    NaN  34266578 -119165392
#
#    lotsizesquarefeet propertycountylandusecode  propertylandusetypeid  \
# 0             1735.0                      1128                    265
# 1                NaN                      1129                    266
# 2             6569.0                      1111                    261
# 3             7400.0                      1110                    261
# 4             6326.0                      1111                    261
#
#   propertyzoningdesc  rawcensustractandblock  regionidcity  regionidcounty  \
# 0                NaN            6.111002e+07       34543.0            2061
# 1                NaN            6.111002e+07       34543.0            2061
# 2                NaN            6.111001e+07       26965.0            2061
# 3                NaN            6.111001e+07       26965.0            2061
# 4                NaN            6.111001e+07       34543.0            2061
#
#    regionidzip  roomcnt  unitcnt  yearbuilt  structuretaxvaluedollarcnt  \
# 0      97081.0      5.0      NaN     1986.0                    115087.0
# 1      97083.0      4.0      NaN     1990.0                    143809.0
# 2      97113.0      5.0      NaN     1956.0                     33619.0
# 3      97113.0      5.0      NaN     1965.0                     45609.0
# 4      97084.0      8.0      NaN     1984.0                    277000.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           191811.0            2015                76724.0    2015.06
# 1           239679.0            2015                95870.0    2581.30
# 2            47853.0            2015                14234.0     591.64
# 3            62914.0            2015                17305.0     682.78
# 4           554000.0            2015               277000.0    5886.92
#
#    censustractandblock  logerror transactiondate  yeardifference
# 0         6.111002e+13    0.0953      2016-01-27            29.0
# 1         6.111002e+13    0.0198      2016-03-30            25.0
# 2         6.111001e+13    0.0060      2016-05-27            59.0
# 3         6.111001e+13   -0.0566      2016-06-07            50.0
# 4         6.111001e+13    0.0573      2016-08-08            31.0

# %% [markdown]
# #### Excluindo as variáveis desnecessárias.

# %%
df.drop(columns=['assessmentyear', 'yearbuilt', 'transactiondate'], axis=1, inplace=True)

# %% [markdown]
# ### Transformando as variáveis para a sua escala original.

# %%
df[['latitude', 'longitude']] = (df[['latitude', 'longitude']])/(10**6)
df['censustractandblock'] = (df['censustractandblock'])/(10**12)
df['rawcensustractandblock'] = (df['rawcensustractandblock'])/(10**6)
df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    NaN
# 1  17088994          1.0         2.0                    NaN
# 2  17100444          2.0         3.0                    NaN
# 3  17102429          1.5         2.0                    NaN
# 4  17109604          2.5         4.0                    NaN
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
#
#    fips  fullbathcnt  heatingorsystemtypeid   latitude   longitude  \
# 0  6111          2.0                    NaN  34.303597 -119.287236
# 1  6111          1.0                    NaN  34.272866 -119.198911
# 2  6111          2.0                    NaN  34.340801 -119.079610
# 3  6111          1.0                    NaN  34.354313 -119.076405
# 4  6111          2.0                    NaN  34.266578 -119.165392
#
#    lotsizesquarefeet propertycountylandusecode  propertylandusetypeid  \
# 0             1735.0                      1128                    265
# 1                NaN                      1129                    266
# 2             6569.0                      1111                    261
# 3             7400.0                      1110                    261
# 4             6326.0                      1111                    261
#
#   propertyzoningdesc  rawcensustractandblock  regionidcity  regionidcounty  \
# 0                NaN               61.110022       34543.0            2061
# 1                NaN               61.110015       34543.0            2061
# 2                NaN               61.110007       26965.0            2061
# 3                NaN               61.110008       26965.0            2061
# 4                NaN               61.110014       34543.0            2061
#
#    regionidzip  roomcnt  unitcnt  structuretaxvaluedollarcnt  \
# 0      97081.0      5.0      NaN                    115087.0
# 1      97083.0      4.0      NaN                    143809.0
# 2      97113.0      5.0      NaN                     33619.0
# 3      97113.0      5.0      NaN                     45609.0
# 4      97084.0      8.0      NaN                    277000.0
#
#    taxvaluedollarcnt  landtaxvaluedollarcnt  taxamount  censustractandblock  \
# 0           191811.0                76724.0    2015.06            61.110022
# 1           239679.0                95870.0    2581.30            61.110015
# 2            47853.0                14234.0     591.64            61.110007
# 3            62914.0                17305.0     682.78            61.110008
# 4           554000.0               277000.0    5886.92            61.110014
#
#    logerror  yeardifference
# 0    0.0953            29.0
# 1    0.0198            25.0
# 2    0.0060            59.0
# 3   -0.0566            50.0
# 4    0.0573            31.0

# %%
df.shape
# Out:
# (30257, 29)

# %% [markdown]
# ### Substituindo os valores missing pelo valor da moda.

# %%
df.isnull().sum()
# Out:
# parcelid                            0
# bathroomcnt                         0
# bedroomcnt                          0
# buildingqualitytypeid           10998
# calculatedbathnbr                 391
# calculatedfinishedsquarefeet      217
# finishedsquarefeet12             1548
# fips                                0
# fullbathcnt                       391
# heatingorsystemtypeid           11429
# latitude                            0
# longitude                           0
# lotsizesquarefeet                3363
# propertycountylandusecode           0
# propertylandusetypeid               0
# propertyzoningdesc              10665
# rawcensustractandblock              0
# regionidcity                      639
# regionidcounty                      0
# regionidzip                        12
# roomcnt                             0
# unitcnt                         10656
# structuretaxvaluedollarcnt        118
# taxvaluedollarcnt                   1
# landtaxvaluedollarcnt               1
# taxamount                           1
# censustractandblock               199
# logerror                            0
# yeardifference                    248
# dtype: int64

# %%
missing_var = [var for var in df.columns if df[var].isnull().sum() > 0]
for var in missing_var:
    df[var] = df[var].fillna(df[var].mode()[0])

# %%
df.isnull().sum()
# Out:
# parcelid                        0
# bathroomcnt                     0
# bedroomcnt                      0
# buildingqualitytypeid           0
# calculatedbathnbr               0
# calculatedfinishedsquarefeet    0
# finishedsquarefeet12            0
# fips                            0
# fullbathcnt                     0
# heatingorsystemtypeid           0
# latitude                        0
# longitude                       0
# lotsizesquarefeet               0
# propertycountylandusecode       0
# propertylandusetypeid           0
# propertyzoningdesc              0
# rawcensustractandblock          0
# regionidcity                    0
# regionidcounty                  0
# regionidzip                     0
# roomcnt                         0
# unitcnt                         0
# structuretaxvaluedollarcnt      0
# taxvaluedollarcnt               0
# landtaxvaluedollarcnt           0
# taxamount                       0
# censustractandblock             0
# logerror                        0
# yeardifference                  0
# dtype: int64

# %% [markdown]
# ### Realizando o encoding das variáveis categóricas.

# %%
cat_vars = [var for var in df.columns if df[var].dtypes=='O']
cat_vars
# Out:
# ['propertycountylandusecode', 'propertyzoningdesc']

# %% [markdown]
# #### Instanciando o Label Encoder.

# %%
encoder = LabelEncoder()

# %%
for i in range(len(cat_vars)):
    var = cat_vars[i]
    var_labels = encoder.fit_transform(df[var])
    var_mappings = {index: label for index, label in enumerate(encoder.classes_)}
    df[(var + '_labels')] = var_labels
    df.drop(columns=var, axis=1, inplace=True)

# %% [markdown]
# #### Verificando os mapeamos de códigos.

# %%
var_mappings
# Out:
# {0: '1NR1*',
#  1: '1NR3*',
#  2: 'AH RM-CD*',
#  3: 'AH RM-CD-F',
#  4: 'AH RS-(3)-',
#  5: 'AHA11*',
#  6: 'AHA110000*',
#  7: 'AHR120000*',
#  8: 'AHR17000*',
#  9: 'AHR17000-C',
#  10: 'AHR17500*',
#  11: 'AHR26250*',
#  12: 'AHR3*',
#  13: 'AHR3-R325U',
#  14: 'AHR335U*',
#  15: 'AHRA20000*',
#  16: 'AHRPD10000',
#  17: 'AHRPD15000',
#  18: 'AHRPD51U*',
#  19: 'AHRPD51U-R',
#  20: 'AHRPD70005',
#  21: 'AHRPD70006',
#  22: 'AHRPD75009',
#  23: 'AHRS-2-200',
#  24: 'ALCBD/DRD*',
#  25: 'ALCP',
#  26: 'ALCPD*',
#  27: 'ALR1*',
#  28: 'ALR165',
#  29: 'ALR1YY',
#  30: 'ALRPD*',
#  31: 'ARR015',
#  32: 'ARR0YY',
#  33: 'ARR1*',
#  34: 'ARR110000&',
#  35: 'ARR110000*',
#  36: 'ARR110000D',
#  37: 'ARR11000D*',
#  38: 'ARR112500*',
#  39: 'ARR175',
#  40: 'ARR17500*',
#  41: 'ARR1D*',
#  42: 'ARR1YY',
#  43: 'ARR2*',
#  44: 'ARR2YY',
#  45: 'ARR3',
#  46: 'ARR3*',
#  47: 'ARR3HY',
#  48: 'ARR3VV',
#  49: 'ARR3YY',
#  50: 'ARRO*',
#  51: 'ARROD*',
#  52: 'ATA10000*',
#  53: 'ATMR',
#  54: 'ATR16000*',
#  55: 'AVC1*',
#  56: 'AVR1*',
#  57: 'AVR2*',
#  58: 'AVR3*',
#  59: 'AVU*',
#  60: 'AZC3*',
#  61: 'AZCBD*',
#  62: 'AZCF*',
#  63: 'AZCFR3BC2*',
#  64: 'AZFS*',
#  65: 'AZP1D*',
#  66: 'AZR1',
#  67: 'AZR1AY',
#  68: 'AZR1B*',
#  69: 'AZR1BY',
#  70: 'AZR1C*',
#  71: 'AZR1C6000*',
#  72: 'AZR1CY',
#  73: 'AZR1YY',
#  74: 'AZR3A*',
#  75: 'AZR3B*',
#  76: 'AZR3C*',
#  77: 'AZR3C1200*',
#  78: 'AZR3C6000*',
#  79: 'AZRA',
#  80: 'AZRZ',
#  81: 'AZW-CF*',
#  82: 'BFA1*',
#  83: 'BFA1-R1600',
#  84: 'BFA106',
#  85: 'BFA1YY',
#  86: 'BFAI*',
#  87: 'BFCG',
#  88: 'BFCG&TC*',
#  89: 'BFCG*',
#  90: 'BFCG-R1*',
#  91: 'BFR1*',
#  92: 'BFR105',
#  93: 'BFR106',
#  94: 'BFR15000*',
#  95: 'BFR16000*',
#  96: 'BFR1YY',
#  97: 'BFR2*',
#  98: 'BFR2PD*',
#  99: 'BFR3*',
#  100: 'BFR3PD*',
#  101: 'BGCMHPD*',
#  102: 'BGM1*',
#  103: 'BGR1*',
#  104: 'BGR3*',
#  105: 'BGR3PD*',
#  106: 'BHR1*',
#  107: 'BHR1YY',
#  108: 'BHR3*',
#  109: 'BHR4*',
#  110: 'BHR475',
#  111: 'BHR4YY',
#  112: 'BLR1YY',
#  113: 'BLR2YY',
#  114: 'BLR3*',
#  115: 'BLR3YY',
#  116: 'BPI*',
#  117: 'BPR1*',
#  118: 'BPR3',
#  119: 'BPR3*',
#  120: 'BPR3PD*',
#  121: 'BPRG*',
#  122: 'BRA1*',
#  123: 'BRR120000*',
#  124: 'BRR17500*',
#  125: 'BUC1*',
#  126: 'BUC2*',
#  127: 'BUC4',
#  128: 'BUR1',
#  129: 'BUR1*',
#  130: 'BUR1HY',
#  131: 'BUR1YY',
#  132: 'BUR2*',
#  133: 'BUR3*',
#  134: 'BUR4*',
#  135: 'BUR4-C2-C3',
#  136: 'BUR5*',
#  137: 'CA&MUR&D*',
#  138: 'CARM12U&D*',
#  139: 'CARM18U&D*',
#  140: 'CARM25U&D*',
#  141: 'CARM25U*',
#  142: 'CARS*',
#  143: 'CASP-4*',
#  144: 'CASP-7*',
#  145: 'CASP-9*',
#  146: 'CC-R3',
#  147: 'CCC3',
#  148: 'CCPD*',
#  149: 'CCR1*',
#  150: 'CCR1AY',
#  151: 'CCR1YY',
#  152: 'CCR2',
#  153: 'CCR2*',
#  154: 'CCR2YY',
#  155: 'CCR3*',
#  156: 'CCR3A*',
#  157: 'CCR4*',
#  158: 'CCR4YY',
#  159: 'CEADP11',
#  160: 'CEADP3',
#  161: 'CEADP4',
#  162: 'CEADP6',
#  163: 'CEADP7',
#  164: 'CECN*',
#  165: 'CERM',
#  166: 'CERS5000',
#  167: 'CERS6500',
#  168: 'CL',
#  169: 'CLCP*',
#  170: 'CLCP-E*',
#  171: 'CLCV*',
#  172: 'CLHC',
#  173: 'CLHC*',
#  174: 'CLI-',
#  175: 'CLRA1*',
#  176: 'CLRM*',
#  177: 'CLRM3000*',
#  178: 'CLRM4000*',
#  179: 'CLRM4000-R',
#  180: 'CLRS*',
#  181: 'CLRS10000*',
#  182: 'CLRS13000&',
#  183: 'CLRS13000*',
#  184: 'CLRS20000*',
#  185: 'CLRS8000*',
#  186: 'CLSP2*',
#  187: 'CMR1YY',
#  188: 'CMR3YY',
#  189: 'COCL*',
#  190: 'COCM*',
#  191: 'COML',
#  192: 'COML*',
#  193: 'COPRH*',
#  194: 'COPRL*',
#  195: 'COPRM*',
#  196: 'COR1*',
#  197: 'COR1YY',
#  198: 'COR2*',
#  199: 'COR3*',
#  200: 'CORA*',
#  201: 'CORH*',
#  202: 'CORL',
#  203: 'CORL*',
#  204: 'CORL-PRH*',
#  205: 'CORM*',
#  206: 'CUR03000*',
#  207: 'CUR1*',
#  208: 'CUR3*',
#  209: 'CVC2*',
#  210: 'CVC3APCD*',
#  211: 'CVC4*',
#  212: 'CVC4PCD*',
#  213: 'CVCPPCD*',
#  214: 'CVE1/2*',
#  215: 'CVM1',
#  216: 'CVM1-C3A*',
#  217: 'CVR1*',
#  218: 'CVR110000*',
#  219: 'CVR11L',
#  220: 'CVR120000*',
#  221: 'CVR171/2',
#  222: 'CVR175',
#  223: 'CVR17500*',
#  224: 'CVR17500PC',
#  225: 'CVR181/2',
#  226: 'CVR18500*',
#  227: 'CVR1YY',
#  228: 'CVR3-RD150',
#  229: 'CVR3-RD300',
#  230: 'CVRD1580*',
#  231: 'CVRD2000*',
#  232: 'CVRD2200',
#  233: 'CVRD3000*',
#  234: 'CVRD3600PC',
#  235: 'CVRD3900*',
#  236: 'DOC1*',
#  237: 'DOHM*',
#  238: 'DOM1',
#  239: 'DOR1&HFB*',
#  240: 'DOR1*',
#  241: 'DOR1-5000*',
#  242: 'DOR1-R1&HF',
#  243: 'DOR105',
#  244: 'DOR105*',
#  245: 'DOR106',
#  246: 'DOR110',
#  247: 'DOR110000*',
#  248: 'DOR1100000',
#  249: 'DOR15000*',
#  250: 'DOR16000*',
#  251: 'DOR171/2',
#  252: 'DOR175',
#  253: 'DOR17500*',
#  254: 'DOR18500*',
#  255: 'DOR1O5*',
#  256: 'DOR2&HFB*',
#  257: 'DOR2*',
#  258: 'DOR3*',
#  259: 'DOR3-C1*',
#  260: 'DOR3-P*',
#  261: 'DOR3-R1500',
#  262: 'DUCR*',
#  263: 'DUR110000*',
#  264: 'DUR16500*',
#  265: 'DUR17500*',
#  266: 'DUR18000*',
#  267: 'DUR1A*',
#  268: 'DUR1AY',
#  269: 'DUR1YY',
#  270: 'DUR3*',
#  271: 'DUR39000*',
#  272: 'DUR4*',
#  273: 'DUR4-C4*',
#  274: 'EM1B*',
#  275: 'EMC3',
#  276: 'EMC3*',
#  277: 'EMC3YY',
#  278: 'EMCO*',
#  279: 'EMR1',
#  280: 'EMR1*',
#  281: 'EMR1A*',
#  282: 'EMR1AY',
#  283: 'EMR1B*',
#  284: 'EMR1BY',
#  285: 'EMR1CY',
#  286: 'EMR1YY',
#  287: 'EMR2*',
#  288: 'EMR2YY',
#  289: 'EMR3*',
#  290: 'EMR3F*',
#  291: 'EMR3YY',
#  292: 'EMR4YY',
#  293: 'EMRIA*',
#  294: 'EMRIC*',
#  295: 'ESCM*',
#  296: 'ESCRS*',
#  297: 'ESM1*',
#  298: 'ESM1YY',
#  299: 'ESR1*',
#  300: 'ESR1YY',
#  301: 'ESR2*',
#  302: 'ESR2YY',
#  303: 'ESR3',
#  304: 'ESR3*',
#  305: 'ESR3YY',
#  306: 'GAASP',
#  307: 'GAHB',
#  308: 'GAR1',
#  309: 'GAR2',
#  310: 'GAR3',
#  311: 'GAR4',
#  312: 'GDCCAP',
#  313: 'GDC_RT66SP',
#  314: 'GDE3',
#  315: 'GDE4',
#  316: 'GDE4_PD4',
#  317: 'GDE5',
#  318: 'GDE6',
#  319: 'GDE6*',
#  320: 'GDE7-20,00',
#  321: 'GDM1A*',
#  322: 'GDR1',
#  323: 'GDR1*',
#  324: 'GDR2',
#  325: 'GDR3',
#  326: 'GDR4*',
#  327: 'GDRHR',
#  328: 'GDR_GA',
#  329: 'GDR_GA_PD',
#  330: 'GDR_LGA',
#  331: 'GDR_VIL_GR',
#  332: 'GLC1YY',
#  333: 'GLC3*',
#  334: 'GLM2YY',
#  335: 'GLR-4',
#  336: 'GLR1(PRD)*',
#  337: 'GLR1*',
#  338: 'GLR1-R*',
#  339: 'GLR171/2',
#  340: 'GLR1R*',
#  341: 'GLR1RY',
#  342: 'GLR1YY',
#  343: 'GLR2*',
#  344: 'GLR3*',
#  345: 'GLR3R*',
#  346: 'GLR3YY',
#  347: 'GLR4',
#  348: 'GLR4*',
#  349: 'GLR4-L',
#  350: 'GLR4P*',
#  351: 'GLR4YY',
#  352: 'GLRIPRD*',
#  353: 'HAH*',
#  354: 'HAM2*',
#  355: 'HAR1*',
#  356: 'HAR1YY',
#  357: 'HAR2*',
#  358: 'HAR3*',
#  359: 'HAR3YY',
#  360: 'HAR4',
#  361: 'HAR4*',
#  362: 'HAR4-R2*',
#  363: 'HASP',
#  364: 'HBC1',
#  365: 'HBR1*',
#  366: 'HBR1YY',
#  367: 'HBR2*',
#  368: 'HBR2B*',
#  369: 'HBR2YY',
#  370: 'HBR3',
#  371: 'HBR3*',
#  372: 'HBR3YY',
#  373: 'HBRP*',
#  374: 'HBRP**',
#  375: 'HBRPYY',
#  376: 'HGR1*',
#  377: 'HGR2*',
#  378: 'HGR3*',
#  379: 'HGR3U25*',
#  380: 'HGR4*',
#  381: 'HHRAS1*',
#  382: 'HPCN*',
#  383: 'HPCP*',
#  384: 'HPCPYY',
#  385: 'HPR1*',
#  386: 'HPR1YY',
#  387: 'HPR2YY',
#  388: 'HPR3*',
#  389: 'HPR3YY',
#  390: 'HPR4*',
#  391: 'HPR4YY',
#  392: 'INCR*',
#  393: 'INGLEWOOD',
#  394: 'INM1L*',
#  395: 'INP1',
#  396: 'INP1VV',
#  397: 'INP1YY',
#  398: 'INR1*',
#  399: 'INR1VV',
#  400: 'INR1YY',
#  401: 'INR2YY',
#  402: 'INR3*',
#  403: 'INR3YY',
#  404: 'INR4*',
#  405: 'IRA1*',
#  406: 'IRC3-A1*',
#  407: 'IRM2',
#  408: 'LAA1',
#  409: 'LAA2',
#  410: 'LAC1',
#  411: 'LAC15000*',
#  412: 'LAC2',
#  413: 'LAC2(PV)',
#  414: 'LAC4',
#  415: 'LAC4(OX)',
#  416: 'LAC5',
#  417: 'LACM',
#  418: 'LACM(GM)',
#  419: 'LACR',
#  420: 'LACR(PKM)',
#  421: 'LACW',
#  422: 'LAM1',
#  423: 'LAM2',
#  424: 'LAM3',
#  425: 'LAMR1',
#  426: 'LAOS',
#  427: 'LAPF',
#  428: 'LAR1',
#  429: 'LAR175',
#  430: 'LAR2',
#  431: 'LAR2-1*',
#  432: 'LAR3',
#  433: 'LAR4',
#  434: 'LAR4(PV)',
#  435: 'LAR5',
#  436: 'LARA',
#  437: 'LARAS3',
#  438: 'LARAS4',
#  439: 'LARD',
#  440: 'LARD1.5',
#  441: 'LARD2',
#  442: 'LARD3',
#  443: 'LARD4',
#  444: 'LARD5',
#  445: 'LARD6',
#  446: 'LARE',
#  447: 'LARE11',
#  448: 'LARE15',
#  449: 'LARE20',
#  450: 'LARE40',
#  451: 'LARE9',
#  452: 'LARI',
#  453: 'LARS',
#  454: 'LARU',
#  455: 'LARW1',
#  456: 'LARZ2.5',
#  457: 'LARZ4',
#  458: 'LARZ5',
#  459: 'LASED',
#  460: 'LAWC',
#  461: 'LBCB',
#  462: 'LBCCA',
#  463: 'LBCCP',
#  464: 'LBCCR',
#  465: 'LBCN',
#  466: 'LBCNR',
#  467: 'LBCO',
#  468: 'LBCP',
#  469: 'LBPD',
#  470: 'LBPD1',
#  471: 'LBPD1*',
#  472: 'LBPD10',
#  473: 'LBPD11',
#  474: 'LBPD14',
#  475: 'LBPD17',
#  476: 'LBPD29',
#  477: 'LBPD30',
#  478: 'LBPD5',
#  479: 'LBPD6',
#  480: 'LBPPD1',
#  481: 'LBPPD2',
#  482: 'LBPPD5',
#  483: 'LBR1L',
#  484: 'LBR1M',
#  485: 'LBR1N',
#  486: 'LBR1N*',
#  487: 'LBR1S',
#  488: 'LBR2A',
#  489: 'LBR2I',
#  490: 'LBR2L',
#  491: 'LBR2N',
#  492: 'LBR2S',
#  493: 'LBR34',
#  494: 'LBR3L*',
#  495: 'LBR3S',
#  496: 'LBR3T',
#  497: 'LBR4N',
#  498: 'LBR4N*',
#  499: 'LBR4R',
#  500: 'LBRM',
#  501: 'LC R418UDP',
#  502: 'LC105*',
#  503: 'LC110000R1',
#  504: 'LCA 22*',
#  505: 'LCA1',
#  506: 'LCA1*',
#  507: 'LCA1-1*',
#  508: 'LCA10000*',
#  509: 'LCA105',
#  510: 'LCA106',
#  511: 'LCA11',
#  512: 'LCA11*',
#  513: 'LCA110000*',
#  514: 'LCA110000D',
#  515: 'LCA115000*',
#  516: 'LCA11DP-R1',
#  517: 'LCA11L',
#  518: 'LCA11OOOO*',
#  519: 'LCA11Y',
#  520: 'LCA12 1/2*',
#  521: 'LCA12*',
#  522: 'LCA120000*',
#  523: 'LCA121/2*',
#  524: 'LCA125000*',
#  525: 'LCA12L',
#  526: 'LCA140000*',
#  527: 'LCA14L',
#  528: 'LCA15*',
#  529: 'LCA15000*',
#  530: 'LCA15Y',
#  531: 'LCA16000*',
#  532: 'LCA16500*',
#  533: 'LCA171/2',
#  534: 'LCA17500*',
#  535: 'LCA1L5',
#  536: 'LCA1YY',
#  537: 'LCA2',
#  538: 'LCA21*',
#  539: 'LCA210',
#  540: 'LCA210*',
#  541: 'LCA210-A22',
#  542: 'LCA210000*',
#  543: 'LCA21OOOO*',
#  544: 'LCA22',
#  545: 'LCA22*',
#  546: 'LCA25*',
#  547: 'LCA2VV',
#  548: 'LCC1*',
#  549: 'LCC1-DP-A1',
#  550: 'LCC1-RA100',
#  551: 'LCC1YY',
#  552: 'LCC2',
#  553: 'LCC2*',
#  554: 'LCC2-R320U',
#  555: 'LCC2-RA*',
#  556: 'LCC3',
#  557: 'LCC3*',
#  558: 'LCC3YY',
#  559: 'LCC4*',
#  560: 'LCC4-R1750',
#  561: 'LCC4-R3-A1',
#  562: 'LCCI',
#  563: 'LCCM*',
#  564: 'LCCPD*',
#  565: 'LCM1',
#  566: 'LCM1*',
#  567: 'LCM1DP*',
#  568: 'LCM2*',
#  569: 'LCP*',
#  570: 'LCPYVV',
#  571: 'LCR1',
#  572: 'LCR1 5000',
#  573: 'LCR1*',
#  574: 'LCR1**',
#  575: 'LCR1-1',
#  576: 'LCR1-20000',
#  577: 'LCR10000*',
#  578: 'LCR101',
#  579: 'LCR105',
#  580: 'LCR105000*',
#  581: 'LCR106',
#  582: 'LCR107',
#  583: 'LCR108',
#  584: 'LCR11*',
#  585: 'LCR110',
#  586: 'LCR110*',
#  587: 'LCR110000',
#  588: 'LCR110000*',
#  589: 'LCR110000-',
#  590: 'LCR111000*',
#  591: 'LCR112000*',
#  592: 'LCR112000-',
#  593: 'LCR112000D',
#  594: 'LCR113000*',
#  595: 'LCR115',
#  596: 'LCR115000*',
#  597: 'LCR115000-',
#  598: 'LCR11L',
#  599: 'LCR11OOOO*',
#  600: 'LCR120',
#  601: 'LCR120000*',
#  602: 'LCR120000-',
#  603: 'LCR12L',
#  604: 'LCR140000&',
#  605: 'LCR140000*',
#  606: 'LCR14L',
#  607: 'LCR15000*',
#  608: 'LCR15OOO*',
#  609: 'LCR16000',
#  610: 'LCR16000*',
#  611: 'LCR16000-R',
#  612: 'LCR16500*',
#  613: 'LCR16OOO*',
#  614: 'LCR17000*',
#  615: 'LCR171/2',
#  616: 'LCR172',
#  617: 'LCR17200*',
#  618: 'LCR175',
#  619: 'LCR17500*',
#  620: 'LCR175OO*',
#  621: 'LCR17OOO*',
#  622: 'LCR18000*',
#  623: 'LCR18000-R',
#  624: 'LCR18500*',
#  625: 'LCR19000*',
#  626: 'LCR19500*',
#  627: 'LCR1L2',
#  628: 'LCR1L5',
#  629: 'LCR1VV',
#  630: 'LCR1YY',
#  631: 'LCR2*',
#  632: 'LCR210000*',
#  633: 'LCR220000*',
#  634: 'LCR27500*',
#  635: 'LCR28000*',
#  636: 'LCR2VV',
#  637: 'LCR2YY',
#  638: 'LCR3',
#  639: 'LCR3*',
#  640: 'LCR3-5000*',
#  641: 'LCR3-A1100',
#  642: 'LCR3-C1*',
#  643: 'LCR3-M11/2',
#  644: 'LCR303',
#  645: 'LCR305',
#  646: 'LCR312UDP*',
#  647: 'LCR315U*',
#  648: 'LCR317UDP*',
#  649: 'LCR320U*',
#  650: 'LCR320UDP*',
#  651: 'LCR326UDP*',
#  652: 'LCR33000',
#  653: 'LCR330U*',
#  654: 'LCR35000*',
#  655: 'LCR3800012',
#  656: 'LCR3800015',
#  657: 'LCR3800025',
#  658: 'LCR3800030',
#  659: 'LCR3DP*',
#  660: 'LCR3P',
#  661: 'LCR3PY',
#  662: 'LCR3VV',
#  663: 'LCR3YY',
#  664: 'LCR4*',
#  665: 'LCR405',
#  666: 'LCR440U*',
#  667: 'LCR4YY',
#  668: 'LCRA 30000',
#  669: 'LCRA*',
#  670: 'LCRA05',
#  671: 'LCRA05*',
#  672: 'LCRA06',
#  673: 'LCRA07',
#  674: 'LCRA08',
#  675: 'LCRA09',
#  676: 'LCRA1*',
#  677: 'LCRA1-A21*',
#  678: 'LCRA10',
#  679: 'LCRA10000*',
#  680: 'LCRA10000-',
#  681: 'LCRA12000*',
#  682: 'LCRA15',
#  683: 'LCRA15000*',
#  684: 'LCRA1L',
#  685: 'LCRA1OOOO-',
#  686: 'LCRA20',
#  687: 'LCRA20000*',
#  688: 'LCRA2L',
#  689: 'LCRA30000*',
#  690: 'LCRA40000*',
#  691: 'LCRA5000*',
#  692: 'LCRA6000*',
#  693: 'LCRA6000-A',
#  694: 'LCRA62',
#  695: 'LCRA6200*',
#  696: 'LCRA7000*',
#  697: 'LCRA71/2',
#  698: 'LCRA75',
#  699: 'LCRA7500',
#  700: 'LCRA7500*',
#  701: 'LCRA7OOO',
#  702: 'LCRA7OOO*',
#  703: 'LCRA9000*',
#  704: 'LCRAL*',
#  705: 'LCRAL2',
#  706: 'LCRAL5',
#  707: 'LCRAYY',
#  708: 'LCRPD',
#  709: 'LCRPD 1 2',
#  710: 'LCRPD 1 2U',
#  711: 'LCRPD 1000',
#  712: 'LCRPD-5000',
#  713: 'LCRPD1-2U*',
#  714: 'LCRPD10000',
#  715: 'LCRPD10001',
#  716: 'LCRPD10U60',
#  717: 'LCRPD11.2U',
#  718: 'LCRPD11.4U',
#  719: 'LCRPD12U',
#  720: 'LCRPD12U*',
#  721: 'LCRPD13.8U',
#  722: 'LCRPD13U-R',
#  723: 'LCRPD15000',
#  724: 'LCRPD1OOOO',
#  725: 'LCRPD1U*',
#  726: 'LCRPD20000',
#  727: 'LCRPD50001',
#  728: 'LCRPD50002',
#  729: 'LCRPD50003',
#  730: 'LCRPD6000',
#  731: 'LCRPD60001',
#  732: 'LCRPD60002',
#  733: 'LCRPD60003',
#  734: 'LCRPD60005',
#  735: 'LCRPD60006',
#  736: 'LCRPD60007',
#  737: 'LCRPD6OOO2',
#  738: 'LCRPD70001',
#  739: 'LCRPD72001',
#  740: 'LCRPD80009',
#  741: 'LCRPD90005',
#  742: 'LCRR*',
#  743: 'LDRUD2500*',
#  744: 'LFR1*',
#  745: 'LFR110000*',
#  746: 'LFR110000-',
#  747: 'LFR115000*',
#  748: 'LFR115000-',
#  749: 'LFR120*',
#  750: 'LFR120000*',
#  751: 'LFR140*',
#  752: 'LFR140000*',
#  753: 'LFR17500*',
#  754: 'LFRPD40000',
#  755: 'LHRA1',
#  756: 'LHRA1*',
#  757: 'LHRA20000*',
#  758: 'LKMF',
#  759: 'LKMFR*',
#  760: 'LKMHP*',
#  761: 'LKPDSF*',
#  762: 'LKR1*',
#  763: 'LKR1-OS*',
#  764: 'LKR17500*',
#  765: 'LKR1YY',
#  766: 'LKRA*',
#  767: 'LKRAYY',
#  768: 'LM PUD*',
#  769: 'LMC4*',
#  770: 'LMPUD*',
#  771: 'LMR1*',
#  772: 'LMR110000*',
#  773: 'LMR110000-',
#  774: 'LMR17500*',
#  775: 'LMR1AWH*',
#  776: 'LMR1AWH-R1',
#  777: 'LMR1B10AWH',
#  778: 'LMR1B15AWH',
#  779: 'LMUD*',
#  780: 'LNC4',
#  781: 'LNM1-B2*',
#  782: 'LNR1*',
#  783: 'LNR1YY',
#  784: 'LNR2*',
#  785: 'LNR2YY',
#  786: 'LNR3*',
#  787: 'LNR3P*',
#  788: 'LNR3PY',
#  789: 'LNR3YY',
#  790: 'LOA1',
#  791: 'LOA1*',
#  792: 'LOCG*',
#  793: 'LOMC*',
#  794: 'LOR1*',
#  795: 'LOR17000*',
#  796: 'LOR17500*',
#  797: 'LOR3*',
#  798: 'LORVD1200*',
#  799: 'LORVD1452*',
#  800: 'LORVD1500*',
#  801: 'LPPUD-C2*',
#  802: 'LPR1*',
#  803: 'LPR106',
#  804: 'LPR16000*',
#  805: 'LPR1YY',
#  806: 'LPR3*',
#  807: 'LPR4*',
#  808: 'LPRE10000*',
#  809: 'LPRS*',
#  810: 'LR-R1OOOO',
#  811: 'LR-R1OOOO*',
#  812: 'LR7000',
#  813: 'LR7OOO*',
#  814: 'LRA 10000*',
#  815: 'LRA22*',
#  816: 'LRC3*',
#  817: 'LRC3-RA650',
#  818: 'LRCM*',
#  819: 'LRCR*',
#  820: 'LRD21*',
#  821: 'LRD22*',
#  822: 'LRMD',
#  823: 'LRMDR*',
#  824: 'LRMDR-1*',
#  825: 'LRR 2 *',
#  826: 'LRR1',
#  827: 'LRR1*',
#  828: 'LRR1-10000',
#  829: 'LRR1-7000',
#  830: 'LRR1-7500*',
#  831: 'LRR10000*',
#  832: 'LRR110000*',
#  833: 'LRR15000*',
#  834: 'LRR16000*',
#  835: 'LRR16000DP',
#  836: 'LRR16500*',
#  837: 'LRR16OOO*',
#  838: 'LRR17000',
#  839: 'LRR17000*',
#  840: 'LRR17500',
#  841: 'LRR17500*',
#  842: 'LRR17OOO*',
#  843: 'LRR2*',
#  844: 'LRR3*',
#  845: 'LRR315UDP*',
#  846: 'LRR320U*',
#  847: 'LRR326.5U*',
#  848: 'LRR36.6UDP',
#  849: 'LRR366UDP*',
#  850: 'LRR6000*',
#  851: 'LRR6OOO*',
#  852: 'LRR7',
#  853: 'LRR7000',
#  854: 'LRR7000*',
#  855: 'LRRA',
#  856: 'LRRA 6000',
#  857: 'LRRA 7000',
#  858: 'LRRA 7500*',
#  859: 'LRRA10000*',
#  860: 'LRRA1OOOO',
#  861: 'LRRA1OOOO-',
#  862: 'LRRA6000',
#  863: 'LRRA6000*',
#  864: 'LRRA6500*',
#  865: 'LRRA7000*',
#  866: 'LRRA7000-R',
#  867: 'LRRA7500',
#  868: 'LRRA7500*',
#  869: 'LRRA75OO*',
#  870: 'LRRI-7000',
#  871: 'LRRI0000',
#  872: 'LRRPD10000',
#  873: 'LRRPD14U*',
#  874: 'LRRPD15UDP',
#  875: 'LRRPD70001',
#  876: 'LRRPD70006',
#  877: 'LRRPD75002',
#  878: 'LRRPD75007',
#  879: 'LRRPD75OO2',
#  880: 'LRRR-1*',
#  881: 'LRRR1*',
#  882: 'LRSP80-01*',
#  883: 'LRSRR*',
#  884: 'LUCR110000',
#  885: 'LVAP*',
#  886: 'LVCPD*',
#  887: 'LVPI',
#  888: 'LVPR10A*',
#  889: 'LVPR15A*',
#  890: 'LVPR2D*',
#  891: 'LVPR3D*',
#  892: 'LVPR4.5D*',
#  893: 'LVPR45D*',
#  894: 'LVPR8A*',
#  895: 'LVR1-PR6A*',
#  896: 'LVR17500*',
#  897: 'LVSP814',
#  898: 'LVSP814*',
#  899: 'LYCB1*',
#  900: 'LYR1',
#  901: 'LYR1*',
#  902: 'LYR1YY',
#  903: 'LYR2*',
#  904: 'LYR2YY',
#  905: 'LYR3*',
#  906: 'LYR3YY',
#  907: 'MA M',
#  908: 'MA-SF-M*',
#  909: 'MBR3*',
#  910: 'MNC1*',
#  911: 'MNCNE',
#  912: 'MNCNE-D5',
#  913: 'MNR1*',
#  914: 'MNR1-RAO*',
#  915: 'MNR1YY',
#  916: 'MNR2YY',
#  917: 'MNR3*',
#  918: 'MNR3YY',
#  919: 'MNR4D46*',
#  920: 'MNR4D46PD*',
#  921: 'MNRH',
#  922: 'MNRM',
#  923: 'MNRPD',
#  924: 'MNRS',
#  925: 'MNRS-D1',
#  926: 'MNRS-D3',
#  927: 'MNRS-D4',
#  928: 'MOM*',
#  929: 'MOM-P/QP*',
#  930: 'MOP/QP*',
#  931: 'MOR2YY',
#  932: 'MORF*',
#  933: 'MORH*',
#  934: 'MORL*',
#  935: 'MORM*',
#  936: 'MORPD*',
#  937: 'MPO/',
#  938: 'MPR1*',
#  939: 'MPR1YY',
#  940: 'MPR2*',
#  941: 'MPR2YY',
#  942: 'MPR3*',
#  943: 'MPR3CD*',
#  944: 'MPR3PD*',
#  945: 'MPR3YY',
#  946: 'MPRL',
#  947: 'MPSP*',
#  948: 'MYR3*',
#  949: 'MYR3PY',
#  950: 'MYR3YY',
#  951: 'NOC3-SPA6*',
#  952: 'NOR1*',
#  953: 'NOR1-P/O(P',
#  954: 'NOR105',
#  955: 'NOR15000*',
#  956: 'NOR1YY',
#  957: 'NOR2*',
#  958: 'NOR3',
#  959: 'NOR3*',
#  960: 'NOR3-20U*',
#  961: 'NOR317U*',
#  962: 'NOR320U*',
#  963: 'NOR3P*',
#  964: 'NOSP2*',
#  965: 'NOSP3-SP4-',
#  966: 'NOSPA1*',
#  967: 'PAM1',
#  968: 'PAM1*',
#  969: 'PAR1*',
#  970: 'PAR1YY',
#  971: 'PAR2*',
#  972: 'PARM*',
#  973: 'PD RPD18U',
#  974: 'PD SFR-3',
#  975: 'PD SFR-Z',
#  976: 'PDA1*',
#  977: 'PDA11*',
#  978: 'PDA12*',
#  979: 'PDA120000*',
#  980: 'PDA2',
#  981: 'PDA2*',
#  982: 'PDA21*',
#  983: 'PDA22*',
#  984: 'PDC1DP*',
#  985: 'PDMA*',
#  986: 'PDMPD-RPD1',
#  987: 'PDR1',
#  988: 'PDR1 7000',
#  989: 'PDR1*',
#  990: 'PDR1-10000',
#  991: 'PDR1-7000',
#  992: 'PDR1-7000*',
#  993: 'PDR1-7OOO*',
#  994: 'PDR110000*',
#  995: 'PDR110000D',
#  996: 'PDR112000*',
#  997: 'PDR120000*',
#  998: 'PDR16000*',
#  999: 'PDR16OOO*',
#  ...}

# %%
df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    7.0
# 1  17088994          1.0         2.0                    7.0
# 2  17100444          2.0         3.0                    7.0
# 3  17102429          1.5         2.0                    7.0
# 4  17109604          2.5         4.0                    7.0
#
#    calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                2.5                        1264.0                1264.0
# 1                1.0                         777.0                 777.0
# 2                2.0                        1101.0                1101.0
# 3                1.5                        1554.0                1554.0
# 4                2.5                        2415.0                2415.0
#
#    fips  fullbathcnt  heatingorsystemtypeid   latitude   longitude  \
# 0  6111          2.0                    2.0  34.303597 -119.287236
# 1  6111          1.0                    2.0  34.272866 -119.198911
# 2  6111          2.0                    2.0  34.340801 -119.079610
# 3  6111          1.0                    2.0  34.354313 -119.076405
# 4  6111          2.0                    2.0  34.266578 -119.165392
#
#    lotsizesquarefeet  propertylandusetypeid  rawcensustractandblock  \
# 0             1735.0                    265               61.110022
# 1             6000.0                    266               61.110015
# 2             6569.0                    261               61.110007
# 3             7400.0                    261               61.110008
# 4             6326.0                    261               61.110014
#
#    regionidcity  regionidcounty  regionidzip  roomcnt  unitcnt  \
# 0       34543.0            2061      97081.0      5.0      1.0
# 1       34543.0            2061      97083.0      4.0      1.0
# 2       26965.0            2061      97113.0      5.0      1.0
# 3       26965.0            2061      97113.0      5.0      1.0
# 4       34543.0            2061      97084.0      8.0      1.0
#
#    structuretaxvaluedollarcnt  taxvaluedollarcnt  landtaxvaluedollarcnt  \
# 0                    115087.0           191811.0                76724.0
# 1                    143809.0           239679.0                95870.0
# 2                     33619.0            47853.0                14234.0
# 3                     45609.0            62914.0                17305.0
# 4                    277000.0           554000.0               277000.0
#
#    taxamount  censustractandblock  logerror  yeardifference  \
# 0    2015.06            61.110022    0.0953            29.0
# 1    2581.30            61.110015    0.0198            25.0
# 2     591.64            61.110007    0.0060            59.0
# 3     682.78            61.110008   -0.0566            50.0
# 4    5886.92            61.110014    0.0573            31.0
#
#    propertycountylandusecode_labels  propertyzoningdesc_labels
# 0                                44                        428
# 1                                45                        428
# 2                                40                        428
# 3                                39                        428
# 4                                40                        428

# %% [markdown]
# ### Verificando Multi-Colinearity:

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Excluindo variáveis com forte correlação.

# %%
df.drop(
    columns=[ 
              'calculatedbathnbr'
             ,'calculatedfinishedsquarefeet'
             ,'structuretaxvaluedollarcnt'
             ,'taxvaluedollarcnt'
             ,'landtaxvaluedollarcnt'
             ,'fullbathcnt'
        ]
        ,axis = 1
        ,inplace = True
    )

# %%
df.head()
# Out:
#    parcelid  bathroomcnt  bedroomcnt  buildingqualitytypeid  \
# 0  17073783          2.5         3.0                    7.0
# 1  17088994          1.0         2.0                    7.0
# 2  17100444          2.0         3.0                    7.0
# 3  17102429          1.5         2.0                    7.0
# 4  17109604          2.5         4.0                    7.0
#
#    finishedsquarefeet12  fips  heatingorsystemtypeid   latitude   longitude  \
# 0                1264.0  6111                    2.0  34.303597 -119.287236
# 1                 777.0  6111                    2.0  34.272866 -119.198911
# 2                1101.0  6111                    2.0  34.340801 -119.079610
# 3                1554.0  6111                    2.0  34.354313 -119.076405
# 4                2415.0  6111                    2.0  34.266578 -119.165392
#
#    lotsizesquarefeet  propertylandusetypeid  rawcensustractandblock  \
# 0             1735.0                    265               61.110022
# 1             6000.0                    266               61.110015
# 2             6569.0                    261               61.110007
# 3             7400.0                    261               61.110008
# 4             6326.0                    261               61.110014
#
#    regionidcity  regionidcounty  regionidzip  roomcnt  unitcnt  taxamount  \
# 0       34543.0            2061      97081.0      5.0      1.0    2015.06
# 1       34543.0            2061      97083.0      4.0      1.0    2581.30
# 2       26965.0            2061      97113.0      5.0      1.0     591.64
# 3       26965.0            2061      97113.0      5.0      1.0     682.78
# 4       34543.0            2061      97084.0      8.0      1.0    5886.92
#
#    censustractandblock  logerror  yeardifference  \
# 0            61.110022    0.0953            29.0
# 1            61.110015    0.0198            25.0
# 2            61.110007    0.0060            59.0
# 3            61.110008   -0.0566            50.0
# 4            61.110014    0.0573            31.0
#
#    propertycountylandusecode_labels  propertyzoningdesc_labels
# 0                                44                        428
# 1                                45                        428
# 2                                40                        428
# 3                                39                        428
# 4                                40                        428

# %% [markdown]
# ### Excluindo variáveis desnecessárias.

# %%
df.drop(columns=['censustractandblock', 'propertycountylandusecode_labels'], axis=1, inplace=True)
df.shape
# Out:
# (30257, 21)

# %% [markdown]
# ### Salvando o dataset em disco.

# %%
df.to_csv('../data/zillow_dataset_final.csv', index=False)
